# %%
import pandas as pd
import json

# %%
df = pd.read_excel("/content/ca3c1f5b-5910-4fe7-892b-a06b01a09c5b.xlsx")

# %%
df.head()
# Out:
#    FEI Number                  Recalling Firm Name Product Type  \
# 0     2522007               Cook Vandergrift, Inc.      Devices
# 1     2429304  Olympus Corporation of the Americas      Devices
# 2     2429304  Olympus Corporation of the Americas      Devices
# 3     2429304  Olympus Corporation of the Americas      Devices
# 4     2429304  Olympus Corporation of the Americas      Devices
#
#   Product Classification   Status  \
# 0               Class II  Ongoing
# 1               Class II  Ongoing
# 2               Class II  Ongoing
# 3               Class II  Ongoing
# 4               Class II  Ongoing
#
#                                 Distribution Pattern Recalling Firm City  \
# 0  Worldwide distribution - US Nationwide includi...         Vandergrift
# 1                        US Nationwide distribution.       Center Valley
# 2                        US Nationwide distribution.       Center Valley
# 3                        US Nationwide distribution.       Center Valley
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426 entries, 0 to 2425
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FEI Number                  2426 non-null   int64
#  1   Recalling Firm Name         2426 non-null   object
#  2   Product Type                2426 non-null   object
#  3   Product Classification      2426 non-null   object
#  4   Status                      2426 non-null   object
#  5   Distribution Pattern        2426 non-null   object
#  6   Recalling Firm City         2426 non-null   object
#  7   Recalling Firm State        2426 non-null   object
#  8   Recalling Firm Country      2426 non-null   object
#  9   Center Classification Date  2426 non-null   datetime64[ns]
#  10  Reason for Recall           2426 non-null   object
#  11  Product Description         2426 non-null   object
#  12  Event ID                    2426 non-null   int64
# ...
